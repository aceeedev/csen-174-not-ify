# %%
from dotenv import load_dotenv
import os

load_dotenv()
key = os.getenv("SPOTIFY_API_KEY")
id = os.getenv("SPOTIFY_API_ID")

import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=id,
                                               client_secret=key,
                                               redirect_uri="http://127.0.0.1:3000",
                                               scope="user-library-read"))

# %%
results = sp.current_user_playlists()
for idx, item in enumerate(results['items']):
    print(f"{idx}, {item['name']}")
# Out:
# 0, Country
# 1, 2000-2010s
# 2, Sectionals
# 3, Chill Rock
# 4, My playlist #21
# 5, 80s
# 6, Tree hugging
# 7, golden age old school wednesday afternoon
# 8, Horse riding music
# 9, My playlist #16
# 10, My playlist #15
# 11, Thinking Music
# 12, Cultural Appropriation
# 13, Playlist #8
# 14, Old People Music
# 15, James
# 16, For once, no 80s music

# %%
print(results['items'][0])
playlistID = results['items'][0]['id']
# Out:
# {'collaborative': False, 'description': '', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/6BFEXW4E8LjjkUGW2djhxu'}, 'href': 'https://api.spotify.com/v1/playlists/6BFEXW4E8LjjkUGW2djhxu', 'id': '6BFEXW4E8LjjkUGW2djhxu', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d00001e0203fd430cb92bf7c49183ab6fab67616d00001e02466a38f72c273a8ac065e9a6ab67616d00001e0294459d3c5af79111a3ef4bbcab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d00001e0203fd430cb92bf7c49183ab6fab67616d00001e02466a38f72c273a8ac065e9a6ab67616d00001e0294459d3c5af79111a3ef4bbcab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d00001e0203fd430cb92bf7c49183ab6fab67616d00001e02466a38f72c273a8ac065e9a6ab67616d00001e0294459d3c5af79111a3ef4bbcab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5', 'width': 60}], 'name': 'Country', 'owner': {'display_name': 'Ambrose', 'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'}, 'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28', 'id': 'dtqyp62534oedsk9di83lxh28', 'type': 'user', 'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'}, 'primary_color': None, 'public': True, 'snapshot_id': 'AAAADwOLnfEo3/cqsYO6JGQCTj7vfHS8', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/6BFEXW4E8LjjkUGW2djhxu/tracks', 'total': 57}, 'type': 'playlist', 'uri': 'spotify:playlist:6BFEXW4E8LjjkUGW2djhxu'}

# %%
playlist = sp.playlist_items(playlist_id=playlistID, market='None')
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6BFEXW4E8LjjkUGW2djhxu/tracks?offset=0&limit=100&market=None&additional_types=track',
#  'items': [{'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 255143,
#     'external_ids': {'isrc': 'USRC12401435'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/311Gvxpueuu4LvWYZ7fwva'},
#     'href': 'https://api.spotify.com/v1/tracks/311Gvxpueuu4LvWYZ7fwva',
#     'id': '311Gvxpueuu4LvWYZ7fwva',
#     'name': 'Disaster',
#     'popularity': 61,
#     'uri': 'spotify:track:311Gvxpueuu4LvWYZ7fwva',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 210898,
#     'external_ids': {'isrc': 'USRC12401436'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CI2BRYoj0600uz0taRh8c'},
#     'href': 'https://api.spotify.com/v1/tracks/5CI2BRYoj0600uz0taRh8c',
#     'id': '5CI2BRYoj0600uz0taRh8c',
#     'name': 'Wasting Time',
#     'popularity': 48,
#     'uri': 'spotify:track:5CI2BRYoj0600uz0taRh8c',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 217307,
#     'external_ids': {'isrc': 'USRC12401057'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0htNDNNRkFmQuESkq4eoqj'},
#     'href': 'https://api.spotify.com/v1/tracks/0htNDNNRkFmQuESkq4eoqj',
#     'id': '0htNDNNRkFmQuESkq4eoqj',
#     'name': 'Wanna Be Loved',
#     'popularity': 74,
#     'uri': 'spotify:track:0htNDNNRkFmQuESkq4eoqj',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 257372,
#     'external_ids': {'isrc': 'USRC12401060'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5XlMj49P3jjmXpAdVGOLyW'},
#     'href': 'https://api.spotify.com/v1/tracks/5XlMj49P3jjmXpAdVGOLyW',
#     'id': '5XlMj49P3jjmXpAdVGOLyW',
#     'name': 'No One Else Like Me',
#     'popularity': 64,
#     'uri': 'spotify:track:5XlMj49P3jjmXpAdVGOLyW',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 152991,
#     'external_ids': {'isrc': 'USRC12401437'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3k057uh5tFgAbWPrQJOTrI'},
#     'href': 'https://api.spotify.com/v1/tracks/3k057uh5tFgAbWPrQJOTrI',
#     'id': '3k057uh5tFgAbWPrQJOTrI',
#     'name': "Ramblin'",
#     'popularity': 50,
#     'uri': 'spotify:track:3k057uh5tFgAbWPrQJOTrI',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 288121,
#     'external_ids': {'isrc': 'USRC12401059'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5vsaspF6wIZOPWNCdHUFLP'},
#     'href': 'https://api.spotify.com/v1/tracks/5vsaspF6wIZOPWNCdHUFLP',
#     'id': '5vsaspF6wIZOPWNCdHUFLP',
#     'name': 'Drowning',
#     'popularity': 70,
#     'uri': 'spotify:track:5vsaspF6wIZOPWNCdHUFLP',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 232252,
#     'external_ids': {'isrc': 'USRC12401058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2RoMQArz1V6uiMerD82sKm'},
#     'href': 'https://api.spotify.com/v1/tracks/2RoMQArz1V6uiMerD82sKm',
#     'id': '2RoMQArz1V6uiMerD82sKm',
#     'name': 'Devil In My Ear',
#     'popularity': 61,
#     'uri': 'spotify:track:2RoMQArz1V6uiMerD82sKm',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 8,
#     'duration_ms': 232552,
#     'external_ids': {'isrc': 'USRC12401438'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1s0B0dkZHfynScpLO0UzJX'},
#     'href': 'https://api.spotify.com/v1/tracks/1s0B0dkZHfynScpLO0UzJX',
#     'id': '1s0B0dkZHfynScpLO0UzJX',
#     'name': "I'm Still Fine",
#     'popularity': 74,
#     'uri': 'spotify:track:1s0B0dkZHfynScpLO0UzJX',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 9,
#     'duration_ms': 204041,
#     'external_ids': {'isrc': 'USRC12401439'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4sI0D6mPtb7Oy9OCTpCU8N'},
#     'href': 'https://api.spotify.com/v1/tracks/4sI0D6mPtb7Oy9OCTpCU8N',
#     'id': '4sI0D6mPtb7Oy9OCTpCU8N',
#     'name': 'On My Knees',
#     'popularity': 54,
#     'uri': 'spotify:track:4sI0D6mPtb7Oy9OCTpCU8N',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 10,
#     'duration_ms': 258142,
#     'external_ids': {'isrc': 'USRC12401440'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0synZpsRWT8bQ8Fz4nPpM3'},
#     'href': 'https://api.spotify.com/v1/tracks/0synZpsRWT8bQ8Fz4nPpM3',
#     'id': '0synZpsRWT8bQ8Fz4nPpM3',
#     'name': 'Moments',
#     'popularity': 58,
#     'uri': 'spotify:track:0synZpsRWT8bQ8Fz4nPpM3',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0UQr4EfIUbii2ufru3mnKe',
#      'id': '0UQr4EfIUbii2ufru3mnKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aa8b71db2fb8f3c2ca3bc6f5',
#        'width': 64}],
#      'name': 'Made by These Moments',
#      'release_date': '2024-07-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0UQr4EfIUbii2ufru3mnKe',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UQr4EfIUbii2ufru3mnKe'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 11,
#     'duration_ms': 221689,
#     'external_ids': {'isrc': 'USRC12401441'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1F7034yDCBuLDj0Yy9xnbZ'},
#     'href': 'https://api.spotify.com/v1/tracks/1F7034yDCBuLDj0Yy9xnbZ',
#     'id': '1F7034yDCBuLDj0Yy9xnbZ',
#     'name': 'God Does',
#     'popularity': 57,
#     'uri': 'spotify:track:1F7034yDCBuLDj0Yy9xnbZ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 200787,
#     'external_ids': {'isrc': 'QZTVM2120623'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/65BmUqyPuH4QLfQjcoJPFL'},
#     'href': 'https://api.spotify.com/v1/tracks/65BmUqyPuH4QLfQjcoJPFL',
#     'id': '65BmUqyPuH4QLfQjcoJPFL',
#     'name': "Stone's Throw",
#     'popularity': 70,
#     'uri': 'spotify:track:65BmUqyPuH4QLfQjcoJPFL',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 339401,
#     'external_ids': {'isrc': 'QZTVM2120624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/714tF0Vt9ohC9uWwEyIRAo'},
#     'href': 'https://api.spotify.com/v1/tracks/714tF0Vt9ohC9uWwEyIRAo',
#     'id': '714tF0Vt9ohC9uWwEyIRAo',
#     'name': 'Moment of Truth',
#     'popularity': 64,
#     'uri': 'spotify:track:714tF0Vt9ohC9uWwEyIRAo',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 255086,
#     'external_ids': {'isrc': 'QZTVM2120625'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4WWotQCVQIU944v4HNbudw'},
#     'href': 'https://api.spotify.com/v1/tracks/4WWotQCVQIU944v4HNbudw',
#     'id': '4WWotQCVQIU944v4HNbudw',
#     'name': 'Do Me Wrong',
#     'popularity': 62,
#     'uri': 'spotify:track:4WWotQCVQIU944v4HNbudw',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 232917,
#     'external_ids': {'isrc': 'QZTVM2120626'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HbzxLqpNVPdiBXvpC7Ovb'},
#     'href': 'https://api.spotify.com/v1/tracks/1HbzxLqpNVPdiBXvpC7Ovb',
#     'id': '1HbzxLqpNVPdiBXvpC7Ovb',
#     'name': 'Wondering Why',
#     'popularity': 82,
#     'uri': 'spotify:track:1HbzxLqpNVPdiBXvpC7Ovb',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 253194,
#     'external_ids': {'isrc': 'QZTVM2120627'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/058reWOvdcoH1s9b4PtCRq'},
#     'href': 'https://api.spotify.com/v1/tracks/058reWOvdcoH1s9b4PtCRq',
#     'id': '058reWOvdcoH1s9b4PtCRq',
#     'name': 'Forgive',
#     'popularity': 59,
#     'uri': 'spotify:track:058reWOvdcoH1s9b4PtCRq',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 217074,
#     'external_ids': {'isrc': 'QZTVM2120628'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4u5H1XvNnaR7gEnLQoCDbe'},
#     'href': 'https://api.spotify.com/v1/tracks/4u5H1XvNnaR7gEnLQoCDbe',
#     'id': '4u5H1XvNnaR7gEnLQoCDbe',
#     'name': 'Heavy Heart',
#     'popularity': 50,
#     'uri': 'spotify:track:4u5H1XvNnaR7gEnLQoCDbe',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 7,
#     'duration_ms': 262892,
#     'external_ids': {'isrc': 'QZTVM2120629'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/38A9kmngXJJ5Rr1e1WpeCL'},
#     'href': 'https://api.spotify.com/v1/tracks/38A9kmngXJJ5Rr1e1WpeCL',
#     'id': '38A9kmngXJJ5Rr1e1WpeCL',
#     'name': 'Ghosts',
#     'popularity': 52,
#     'uri': 'spotify:track:38A9kmngXJJ5Rr1e1WpeCL',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:56:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1TGX3TzhBOkAOWyoS3TWVF',
#      'id': '1TGX3TzhBOkAOWyoS3TWVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303fd430cb92bf7c49183ab6f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203fd430cb92bf7c49183ab6f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103fd430cb92bf7c49183ab6f',
#        'width': 64}],
#      'name': 'Moment of Truth',
#      'release_date': '2022-04-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1TGX3TzhBOkAOWyoS3TWVF',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#        'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#        'id': '6IKlXZEFOvk9itrP1s0knJ',
#        'name': 'The Red Clay Strays',
#        'type': 'artist',
#        'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IKlXZEFOvk9itrP1s0knJ'},
#       'href': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ',
#       'id': '6IKlXZEFOvk9itrP1s0knJ',
#       'name': 'The Red Clay Strays',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IKlXZEFOvk9itrP1s0knJ'}],
#     'disc_number': 1,
#     'track_number': 8,
#     'duration_ms': 206302,
# ...
#     'href': 'https://api.spotify.com/v1/tracks/2JaIIUKcFXkgMRL3v3mZEK',
#     'id': '2JaIIUKcFXkgMRL3v3mZEK',
#     'name': 'Bottles and Bibles (Live)',
#     'popularity': 53,
#     'uri': 'spotify:track:2JaIIUKcFXkgMRL3v3mZEK',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T06:59:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/0R8H8XYAiHsh2dwzb4RHsI',
#      'id': '0R8H8XYAiHsh2dwzb4RHsI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27333a9bf581d86e303313771d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0233a9bf581d86e303313771d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485133a9bf581d86e303313771d6',
#        'width': 64}],
#      'name': 'Colter Wall',
#      'release_date': '2017-05-12',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0R8H8XYAiHsh2dwzb4RHsI',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xYXYzm9H3RzyQgBrYwIcx'},
#        'href': 'https://api.spotify.com/v1/artists/3xYXYzm9H3RzyQgBrYwIcx',
#        'id': '3xYXYzm9H3RzyQgBrYwIcx',
#        'name': 'Colter Wall',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xYXYzm9H3RzyQgBrYwIcx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0R8H8XYAiHsh2dwzb4RHsI'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xYXYzm9H3RzyQgBrYwIcx'},
#       'href': 'https://api.spotify.com/v1/artists/3xYXYzm9H3RzyQgBrYwIcx',
#       'id': '3xYXYzm9H3RzyQgBrYwIcx',
#       'name': 'Colter Wall',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xYXYzm9H3RzyQgBrYwIcx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/13ZEDW6vyBF12HYcZRr4EV'},
#       'href': 'https://api.spotify.com/v1/artists/13ZEDW6vyBF12HYcZRr4EV',
#       'id': '13ZEDW6vyBF12HYcZRr4EV',
#       'name': 'Tyler Childers',
#       'type': 'artist',
#       'uri': 'spotify:artist:13ZEDW6vyBF12HYcZRr4EV'}],
#     'disc_number': 1,
#     'track_number': 10,
#     'duration_ms': 143000,
#     'external_ids': {'isrc': 'USG9K1700110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/65UNQSH7RI4Lxw7VrXMp5y'},
#     'href': 'https://api.spotify.com/v1/tracks/65UNQSH7RI4Lxw7VrXMp5y',
#     'id': '65UNQSH7RI4Lxw7VrXMp5y',
#     'name': 'Fraulein (feat. Tyler Childers)',
#     'popularity': 65,
#     'uri': 'spotify:track:65UNQSH7RI4Lxw7VrXMp5y',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T07:02:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2037mw8neL72exAlwyoCSc',
#      'id': '2037mw8neL72exAlwyoCSc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caa3dad25a4da89903c57be3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caa3dad25a4da89903c57be3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caa3dad25a4da89903c57be3',
#        'width': 64}],
#      'name': 'Family Ties',
#      'release_date': '2023-09-22',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2037mw8neL72exAlwyoCSc',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ErsJAz6qJ5cqjoVAvfvaC'},
#        'href': 'https://api.spotify.com/v1/artists/2ErsJAz6qJ5cqjoVAvfvaC',
#        'id': '2ErsJAz6qJ5cqjoVAvfvaC',
#        'name': 'Charles Wesley Godwin',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ErsJAz6qJ5cqjoVAvfvaC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2037mw8neL72exAlwyoCSc'},
#      'total_tracks': 19},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ErsJAz6qJ5cqjoVAvfvaC'},
#       'href': 'https://api.spotify.com/v1/artists/2ErsJAz6qJ5cqjoVAvfvaC',
#       'id': '2ErsJAz6qJ5cqjoVAvfvaC',
#       'name': 'Charles Wesley Godwin',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ErsJAz6qJ5cqjoVAvfvaC'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 228346,
#     'external_ids': {'isrc': 'QZ22S2300133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5etrSAugIe3FXuG6em9Atj'},
#     'href': 'https://api.spotify.com/v1/tracks/5etrSAugIe3FXuG6em9Atj',
#     'id': '5etrSAugIe3FXuG6em9Atj',
#     'name': 'All Again',
#     'popularity': 70,
#     'uri': 'spotify:track:5etrSAugIe3FXuG6em9Atj',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T07:05:24Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2a0WpuqyjACGd5VmXflGu7',
#      'id': '2a0WpuqyjACGd5VmXflGu7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f3fd73779292c2a3cefc4e4c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f3fd73779292c2a3cefc4e4c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f3fd73779292c2a3cefc4e4c',
#        'width': 64}],
#      'name': 'How the Mighty Fall',
#      'release_date': '2021-11-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2a0WpuqyjACGd5VmXflGu7',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ErsJAz6qJ5cqjoVAvfvaC'},
#        'href': 'https://api.spotify.com/v1/artists/2ErsJAz6qJ5cqjoVAvfvaC',
#        'id': '2ErsJAz6qJ5cqjoVAvfvaC',
#        'name': 'Charles Wesley Godwin',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ErsJAz6qJ5cqjoVAvfvaC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2a0WpuqyjACGd5VmXflGu7'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ErsJAz6qJ5cqjoVAvfvaC'},
#       'href': 'https://api.spotify.com/v1/artists/2ErsJAz6qJ5cqjoVAvfvaC',
#       'id': '2ErsJAz6qJ5cqjoVAvfvaC',
#       'name': 'Charles Wesley Godwin',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ErsJAz6qJ5cqjoVAvfvaC'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 231672,
#     'external_ids': {'isrc': 'QZF8D2100101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MyxpCWldoyrKvB61kahpS'},
#     'href': 'https://api.spotify.com/v1/tracks/7MyxpCWldoyrKvB61kahpS',
#     'id': '7MyxpCWldoyrKvB61kahpS',
#     'name': 'Jesse',
#     'popularity': 56,
#     'uri': 'spotify:track:7MyxpCWldoyrKvB61kahpS',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T16:26:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4Ciw110gdWtwcleY7KQMRI',
#      'id': '4Ciw110gdWtwcleY7KQMRI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea31dc8d8f06024356e0ba1f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea31dc8d8f06024356e0ba1f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea31dc8d8f06024356e0ba1f',
#        'width': 64}],
#      'name': 'Bad For You',
#      'release_date': '2020-02-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4Ciw110gdWtwcleY7KQMRI',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bLSAQPeix7Xm2e5Gtn48R'},
#        'href': 'https://api.spotify.com/v1/artists/3bLSAQPeix7Xm2e5Gtn48R',
#        'id': '3bLSAQPeix7Xm2e5Gtn48R',
#        'name': 'The Steeldrivers',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bLSAQPeix7Xm2e5Gtn48R'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Ciw110gdWtwcleY7KQMRI'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bLSAQPeix7Xm2e5Gtn48R'},
#       'href': 'https://api.spotify.com/v1/artists/3bLSAQPeix7Xm2e5Gtn48R',
#       'id': '3bLSAQPeix7Xm2e5Gtn48R',
#       'name': 'The Steeldrivers',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bLSAQPeix7Xm2e5Gtn48R'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 209256,
#     'external_ids': {'isrc': 'USRO21901878'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6vBOgkPAZ0dY2CQf5sY9HK'},
#     'href': 'https://api.spotify.com/v1/tracks/6vBOgkPAZ0dY2CQf5sY9HK',
#     'id': '6vBOgkPAZ0dY2CQf5sY9HK',
#     'name': 'The Bartender',
#     'popularity': 52,
#     'uri': 'spotify:track:6vBOgkPAZ0dY2CQf5sY9HK',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-07-31T22:50:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6CK1jZY2doBQEk05reOFmu',
#      'id': '6CK1jZY2doBQEk05reOFmu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301430c6460e2331f062744e3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201430c6460e2331f062744e3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101430c6460e2331f062744e3',
#        'width': 64}],
#      'name': 'Mountain Girl',
#      'release_date': '2018-11-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6CK1jZY2doBQEk05reOFmu',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4pLxUMyDrijXynrUP59whJ'},
#        'href': 'https://api.spotify.com/v1/artists/4pLxUMyDrijXynrUP59whJ',
#        'id': '4pLxUMyDrijXynrUP59whJ',
#        'name': 'Shane Smith & the Saints',
#        'type': 'artist',
#        'uri': 'spotify:artist:4pLxUMyDrijXynrUP59whJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6CK1jZY2doBQEk05reOFmu'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4pLxUMyDrijXynrUP59whJ'},
#       'href': 'https://api.spotify.com/v1/artists/4pLxUMyDrijXynrUP59whJ',
#       'id': '4pLxUMyDrijXynrUP59whJ',
#       'name': 'Shane Smith & the Saints',
#       'type': 'artist',
#       'uri': 'spotify:artist:4pLxUMyDrijXynrUP59whJ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 208746,
#     'external_ids': {'isrc': 'QMK9C1800002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5gtVQWEwg06Zp53UE6D28j'},
#     'href': 'https://api.spotify.com/v1/tracks/5gtVQWEwg06Zp53UE6D28j',
#     'id': '5gtVQWEwg06Zp53UE6D28j',
#     'name': 'Mountain Girl',
#     'popularity': 55,
#     'uri': 'spotify:track:5gtVQWEwg06Zp53UE6D28j',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-08-05T18:21:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dtqyp62534oedsk9di83lxh28'},
#     'href': 'https://api.spotify.com/v1/users/dtqyp62534oedsk9di83lxh28',
#     'id': 'dtqyp62534oedsk9di83lxh28',
#     'type': 'user',
#     'uri': 'spotify:user:dtqyp62534oedsk9di83lxh28'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/38DbwWdACUMpVMfRTxGnvi',
#      'id': '38DbwWdACUMpVMfRTxGnvi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d76849334e7d661ae9053e2a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d76849334e7d661ae9053e2a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d76849334e7d661ae9053e2a',
#        'width': 64}],
#      'name': 'Can I Take My Hounds to Heaven?',
#      'release_date': '2022-09-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:38DbwWdACUMpVMfRTxGnvi',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13ZEDW6vyBF12HYcZRr4EV'},
#        'href': 'https://api.spotify.com/v1/artists/13ZEDW6vyBF12HYcZRr4EV',
#        'id': '13ZEDW6vyBF12HYcZRr4EV',
#        'name': 'Tyler Childers',
#        'type': 'artist',
#        'uri': 'spotify:artist:13ZEDW6vyBF12HYcZRr4EV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38DbwWdACUMpVMfRTxGnvi'},
#      'total_tracks': 24},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13ZEDW6vyBF12HYcZRr4EV'},
#       'href': 'https://api.spotify.com/v1/artists/13ZEDW6vyBF12HYcZRr4EV',
#       'id': '13ZEDW6vyBF12HYcZRr4EV',
#       'name': 'Tyler Childers',
#       'type': 'artist',
#       'uri': 'spotify:artist:13ZEDW6vyBF12HYcZRr4EV'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 244173,
#     'external_ids': {'isrc': 'USRC12201393'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0xTDZzwnSK3t8FfAbrvAiU'},
#     'href': 'https://api.spotify.com/v1/tracks/0xTDZzwnSK3t8FfAbrvAiU',
#     'id': '0xTDZzwnSK3t8FfAbrvAiU',
#     'name': 'Can I Take My Hounds to Heaven? - Hallelujah Version',
#     'popularity': 54,
#     'uri': 'spotify:track:0xTDZzwnSK3t8FfAbrvAiU',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 57}
